# %% [markdown]
# # Proyecto Final ('Plants_To_Plant')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings                                              
from sklearn.exceptions import DataConversionWarning          
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

# %%
df = pd.read_csv('C:/Users/FX506/OneDrive/Escritorio/PPP/CSV/plants_details.csv', encoding='latin-1')

df.head(2)
# Out:
#    S.No            Name         Family         Genus         Order   Kingdom  \
# 0     1         Jasmine       Oleaceae  Jasminum; L.      Lamiales   Plantae
# 1     2  Curcuma caesia  Zingiberaceae       Curcuma  Zingiberales   Plantae
#
#   Suitable Soil pH
# 0          4.9-8.3
# 1          4.5-6.5

# %%
df = df.drop('Kingdom', axis=1)

df = df.drop('S.No', axis=1)

# %%
df.head(60)
# Out:
#                              Name          Family              Genus  \
# 0                         Jasmine        Oleaceae       Jasminum; L.
# 1                  Curcuma caesia   Zingiberaceae            Curcuma
# 2                      Curry Tree        Rutaceae            Murraya
# 3               Indian gooseberry  Phyllanthaceae        Phyllanthus
# 4                        Hibiscus       Malvaceae           Hibiscus
# 5                      Rose apple       Myrtaceae           Syzygium
# 6   Passiflora incarnata (Purple)  Passifloraceae         Passiflora
# 7          White-fleshed pitahaya       Cactaceae       Selenicereus
# 8                  Chrysanthemums      Asteraceae      Chrysanthemum
# 9                          Mentha           Mints             Mentha
# 10                      Sapodilla      Sapotaceae          Manilkara
# 11                    Snake gourd   Cucurbitaceae      Trichosanthes
# 12                       Key lime        Rutaceae             Citrus
# ...

# %%
df2 = pd.read_csv('C:/Users/FX506/OneDrive/Escritorio/PPP/CSV/2do_df.csv')

df2.head(2)
# Out:
#    nombre      familia       genero          orden sustrato_ph
# 0    Rose     Rosaceae         Rosa  Magnoliopsida  pH 6.0-7.0
# 1  Orchid  Orchidaceae  Orchidaceae     Liliopsida  pH 5.5-6.5

# %%
df2 = df2.rename(columns={'nombre': 'Name', 'familia': 'Family', 'genero': 'Genus', 'orden': 'Order', 'sustrato_ph': 'Suitable Soil pH'})

# %%
df2.columns
# Out:
# Index(['Name', 'Family', 'Genus', 'Order', 'Suitable Soil pH'], dtype='object')

# %%
df.columns
# Out:
# Index(['Name', 'Family', 'Genus', 'Order', 'Suitable Soil pH'], dtype='object')

# %%
import pandas as pd

# DataFrame original
otro_df = df
# DataFrame con las filas a agregar
mi_df = df2
# Agregar las filas de mi_df a otro_df
resultado = otro_df.append(mi_df, ignore_index=True)

# Imprimir el DataFrame resultante
print(resultado)
# Out:
#                              Name           Family              Genus  \
# 0                         Jasmine         Oleaceae       Jasminum; L.
# 1                  Curcuma caesia    Zingiberaceae            Curcuma
# 2                      Curry Tree         Rutaceae            Murraya
# 3               Indian gooseberry   Phyllanthaceae        Phyllanthus
# 4                        Hibiscus        Malvaceae           Hibiscus
# 5                      Rose apple        Myrtaceae           Syzygium
# 6   Passiflora incarnata (Purple)   Passifloraceae         Passiflora
# 7          White-fleshed pitahaya        Cactaceae       Selenicereus
# 8                  Chrysanthemums       Asteraceae      Chrysanthemum
# 9                          Mentha            Mints             Mentha
# 10                      Sapodilla       Sapotaceae          Manilkara
# 11                    Snake gourd    Cucurbitaceae      Trichosanthes
# ...

# %%
resultado.shape
# Out:
# (90, 5)

# %%
duplicados = resultado.duplicated()

dff = resultado.drop_duplicates()

# %%
dff.shape
# Out:
# (86, 5)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              86 non-null     object
#  1   Family            86 non-null     object
#  2   Genus             86 non-null     object
#  3   Order             86 non-null     object
#  4   Suitable Soil pH  85 non-null     object
# dtypes: object(5)
# memory usage: 4.0+ KB

# %%
dff.dropna(inplace=True)
# Out:
# C:\Users\FX506\AppData\Local\Temp\ipykernel_33496\601264983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff.dropna(inplace=True)

# %%
dff.reset_index(inplace=True)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
dff = dff.drop('index', axis=1)

# %%
dff
# Out:
#                              Name           Family              Genus  \
# 0                         Jasmine         Oleaceae       Jasminum; L.
# 1                  Curcuma caesia    Zingiberaceae            Curcuma
# 2                      Curry Tree         Rutaceae            Murraya
# 3               Indian gooseberry   Phyllanthaceae        Phyllanthus
# 4                        Hibiscus        Malvaceae           Hibiscus
# 5                      Rose apple        Myrtaceae           Syzygium
# 6   Passiflora incarnata (Purple)   Passifloraceae         Passiflora
# 7          White-fleshed pitahaya        Cactaceae       Selenicereus
# 8                  Chrysanthemums       Asteraceae      Chrysanthemum
# 9                          Mentha            Mints             Mentha
# 10                      Sapodilla       Sapotaceae          Manilkara
# 11                    Snake gourd    Cucurbitaceae      Trichosanthes
# ...

# %%
dff['Suitable Soil pH'] = dff['Suitable Soil pH'].str.replace('pH', '')

# %%
dff['Name'].unique()
# Out:
# array(['Jasmine', 'Curcuma caesia', 'Curry Tree', 'Indian gooseberry',
#        'Hibiscus', 'Rose apple', 'Passiflora incarnata (Purple)',
#        'White-fleshed pitahaya', 'Chrysanthemums', 'Mentha', 'Sapodilla',
#        'Snake gourd', 'Key lime', 'Cucumber', 'Trailing arbutus', 'Betel',
#        'Rose ', 'Wild sweetsop', 'Jack tree', 'Cymbopogon citratus',
#        'Amorphophallus paeoniifolius', 'Chamaecostus cuspidatus',
#        'Nyctanthes arbor-tristis', 'Amaranthus', 'Calabash',
#        'Saussurea obvallata\xa0', 'Leonotis nepetifolia',
#        'Lawsonia inermis(Henna)', 'Spine gourd', 'Clitoria ternatea',
#        'Ziziphus mauritiana', 'Tinospora cordifolia', 'Moringa oleifera',
#        'Mangifera indica', 'Echinochloa colona', 'Ocimum tenuiflorum',
#        'Ajwain', 'Camellia sinensis', 'Aegle marmelos',
#        'Epipremnum aureum', 'Rose', 'Orchid', 'Tomato', 'Sunflower',
#        'Lavender', 'Fern', 'Ficus', 'Jade Plant', 'Tulip', 'Cactus',
# ...

# %%
dff = dff.drop(dff[dff['Name'] == 'rose '].index)

# %%
dff = dff.drop(dff[dff['Name'] == 'Mint'].index)

# %%
dff = dff.drop(dff[dff['Name'] == 'Chrysanthemum'].index)

# %%
dff
# Out:
#                              Name           Family              Genus  \
# 0                         Jasmine         Oleaceae       Jasminum; L.
# 1                  Curcuma caesia    Zingiberaceae            Curcuma
# 2                      Curry Tree         Rutaceae            Murraya
# 3               Indian gooseberry   Phyllanthaceae        Phyllanthus
# 4                        Hibiscus        Malvaceae           Hibiscus
# 5                      Rose apple        Myrtaceae           Syzygium
# 6   Passiflora incarnata (Purple)   Passifloraceae         Passiflora
          'Carnation': 'periodically (1 per week)', 
          'Lily': 'periodically (1 per week)', 
          'Basil': 'periodically (1 per week)', 
          'Snake Plant': 'periodically (1 per 2-4 weeks)', 
          'Anthurium': 'periodically (1 per week)',
          'Hydrangea': 'regularly (3 per week)', 
          'Aloe Vera': 'periodically (1 per 3-4 weeks)', 
          'Peperomia': 'periodically (1 per 2-3 weeks)', 
          'Rosemary': 'periodically (1 per 7-10 days)', 
          'Strawberry': 'regularly (3 per week)', 
          'African Violet': 'periodically (1 per week)',
          'Begonia': 'periodically (1 per week)', 
          'Marigold': 'periodically (1 per week)', 
          'Tree Aloe': 'periodically (1 per 2-3 weeks)', 
          'Dahlia': 'periodically (1 per week)', 
          'Gazania': 'periodically (1 per 2-3 weeks)', 
          'Ivy': 'periodically (1 per week)', 
          'Croton': 'regularly (1 per week)', 
          'Petunia': 'periodically (1 per week)',
          'Climbing Hydrangea': 'regularly (2-3 per week)', 
          'Sea Lavender': 'periodically (1 per week)', 
          'Alder': 'periodically (1 per week)', 
          'Eucalyptus': 'periodically (1 per 2-3 weeks)', 
          'Venus Flytrap': 'constantly (always need wet soil)', 
          'Water Lily': 'constantly (grow on water)', 
          'Catnip': 'periodically (1 per week)', 
          'Pansy': 'periodically (1 per week)', 
          'Swedish Ivy': 'periodically (1 per week)', 
          'Boston Fern': 'regularly (2-3 per week)'}

# %%
# Crea la nueva columna "Watering Frequency" y asigna los valores del diccionario
dff['Watering Frequency'] = dff['Name'].map(dictio)

# %%
dff = dff.drop(dff[dff['Name'] == 'Rose'].index)

# %%
dff = dff.drop(dff[dff['Name'] == 'Saussurea obvallata'].index)

# %%
dictio2 = {
    'Jasmine': 'Outdoor',
    'Curcuma caesia': 'Outdoor',
    'Curry Tree': 'Outdoor',
    'Indian gooseberry': 'Outdoor',
    'Hibiscus': 'Outdoor',
    'Rose apple': 'Outdoor',
    'Passiflora incarnata (Purple)': 'Outdoor',
    'White-fleshed pitahaya': 'Outdoor',
    'Chrysanthemums': 'Outdoor',
    'Mentha': 'Outdoor',
    'Sapodilla': 'Outdoor',
    'Snake gourd': 'Outdoor',
    'Key lime': 'Outdoor',
    'Cucumber': 'Outdoor',
    'Trailing arbutus': 'Outdoor',
    'Betel': 'Outdoor',
    'Wild sweetsop': 'Outdoor',
    'Jack tree': 'Outdoor',
    'Cymbopogon citratus': 'Outdoor',
    'Amorphophallus paeoniifolius': 'Outdoor',
    'Chamaecostus cuspidatus': 'Outdoor',
    'Nyctanthes arbor-tristis': 'Outdoor',
    'Amaranthus': 'Outdoor',
    'Calabash': 'Outdoor',
    'Leonotis nepetifolia': 'Outdoor',
    'Lawsonia inermis (Henna)': 'Outdoor',
    'Spine gourd': 'Outdoor',
    'Clitoria ternatea': 'Outdoor',
    'Ziziphus mauritiana': 'Outdoor',
    'Tinospora cordifolia': 'Outdoor',
    'Moringa oleifera': 'Outdoor',
    'Mangifera indica': 'Outdoor',
    'Echinochloa colona': 'Outdoor',
    'Ocimum tenuiflorum': 'Outdoor',
    'Ajwain': 'Outdoor',
    'Camellia sinensis': 'Outdoor',
    'Aegle marmelos': 'Outdoor',
    'Epipremnum aureum': 'Indoor',
    'Orchid': 'Indoor',
    'Tomato': 'Outdoor',
    'Sunflower': 'Outdoor',
    'Lavender': 'Outdoor',
    'Fern': 'Indoor',
    'Ficus': 'Indoor',
    'Jade Plant': 'Indoor',
    'Tulip': 'Outdoor',
    'Cactus': 'Indoor/Outdoor',
    'Peony': 'Outdoor',
    'Calla Lily': 'Outdoor/Indoor',
    'Geranium': 'Outdoor/Indoor',
    'Carnation': 'Outdoor/Indoor',
    'Lily': 'Outdoor/Indoor',
    'Basil': 'Indoor',
    'Snake Plant': 'Indoor',
    'Anthurium': 'Indoor',
    'Hydrangea': 'Outdoor',
    'Aloe Vera': 'Indoor',
    'Peperomia': 'Indoor',
    'Rosemary': 'Outdoor/Indoor',
    'Strawberry': 'Outdoor',
    'African Violet': 'Indoor',
    'Begonia': 'Outdoor/Indoor',
    'Marigold': 'Outdoor',
    'Tree Aloe': 'Outdoor',
    'Dahlia': 'Outdoor',
    'Gazania': 'Outdoor',
    'Ivy': 'Indoor/Outdoor',
    'Croton': 'Indoor/Outdoor',
    'Petunia': 'Outdoor/Indoor',
    'Climbing Hydrangea': 'Outdoor',
    'Sea Lavender': 'Outdoor',
    'Alder': 'Outdoor',
    'Eucalyptus': 'Outdoor',
    'Venus Flytrap': 'Indoor',
    'Water Lily': 'Outdoor',
    'Catnip': 'Outdoor/Indoor',
    'Pansy': 'Outdoor/Indoor',
    'Swedish Ivy': 'Indoor',
    'Boston Fern': 'Indoor'
}

# %%
dff['Placement'] = dff['Name'].map(dictio2)

# %%
dff = dff.dropna()

# %%
dff.reset_index(inplace=True)

# %%
dff = dff.drop('index', axis=1)

# %%
dff.head()
# Out:
#                 Name          Family         Genus         Order  \
# 0            Jasmine        Oleaceae  Jasminum; L.      Lamiales
# 1     Curcuma caesia   Zingiberaceae       Curcuma  Zingiberales
# 2         Curry Tree        Rutaceae       Murraya    Sapindales
# 3  Indian gooseberry  Phyllanthaceae   Phyllanthus  Malpighiales
# 4           Hibiscus       Malvaceae      Hibiscus      Malvales
#
#   Suitable Soil pH        Watering Frequency Placement
# 0          4.9-8.3  regularly (2-3 per week)   Outdoor
# 1          4.5-6.5    regularly (2 per week)   Outdoor
# 2            5.6-6    regularly (2 per week)   Outdoor
# 3          6.5-9.5  regularly (2-3 per week)   Outdoor
# 4          5.5-6.5  regularly (1-2 per week)   Outdoor

# %%
dff['Placement'].unique()
# Out:
# array(['Outdoor', 'Indoor', 'Indoor/Outdoor', 'Outdoor/Indoor'],
#       dtype=object)

# %%
dff['Placement'] = dff['Placement'].replace('Indoor/Outdoor', 'Both')
dff['Placement'] = dff['Placement'].replace('Outdoor/Indoor', 'Both')

# %%
dff.head()
# Out:
#                 Name          Family         Genus         Order  \
# 0            Jasmine        Oleaceae  Jasminum; L.      Lamiales
# 1     Curcuma caesia   Zingiberaceae       Curcuma  Zingiberales
# 2         Curry Tree        Rutaceae       Murraya    Sapindales
# 3  Indian gooseberry  Phyllanthaceae   Phyllanthus  Malpighiales
# 4           Hibiscus       Malvaceae      Hibiscus      Malvales
#
#   Suitable Soil pH        Watering Frequency Placement
# 0          4.9-8.3  regularly (2-3 per week)   Outdoor
# 1          4.5-6.5    regularly (2 per week)   Outdoor
# 2            5.6-6    regularly (2 per week)   Outdoor
# 3          6.5-9.5  regularly (2-3 per week)   Outdoor
# 4          5.5-6.5  regularly (1-2 per week)   Outdoor

# %%
dictio3 = {'Jasmine': '6,6', 
          'Curcuma caesia': '5,5', 
          'Curry Tree': '5,8', 
          'Indian gooseberry': '8,0', 
          'Hibiscus': '6,0',
          'Rose apple': '6,0', 
          'Passiflora incarnata (Purple)': '6,8', 
          'White-fleshed pitahaya': '6,0', 
          'Chrysanthemums': '6,0', 
          'Mentha': '6,7',
          'Sapodilla': '7,0', 
          'Snake gourd': '6,5', 
          'Key lime': '6,5', 
          'Cucumber': '7,2', 
          'Trailing arbutus': '6,5', 
          'Betel': '7,2',
          'Rose': '6,4',
          'Wild sweetsop': '6,9', 
          'Jack tree': '6,5', 
          'Cymbopogon citratus': '6,2', 
          'Amorphophallus paeoniifolius': '5,4', 
          'Chamaecostus cuspidatus': '6,2',
          'Nyctanthes arbor-tristis': '7,0', 
          'Amaranthus': '5,8', 
          'Calabash': '6,2', 
          'Saussurea obvallata': '7,0', 
          'Leonotis nepetifolia': '5,8',
          'Lawsonia inermis(Henna)': '6,2', 
          'Spine gourd': '7,0', 
          'Clitoria ternatea': '5,5', 
          'Ziziphus mauritiana': '6,5', 
          'Tinospora cordifolia': '7,2',  
          'Moringa oleifera': '9,2', 
          'Mangifera indica': '6,9', 
          'Echinochloa colona': '6,5', 
          'Ocimum tenuiflorum': '6,5', 
          'Ajwain': '6,0',
          'Camellia sinensis': '6,7', 
          'Aegle marmelos': '7,0', 
          'Epipremnum aureum': '4,2', 
          'Rose': '5,0', 
          'Orchid': '6,3', 
          'Tomato': '6,0',
          'Sunflower': '6,5', 
          'Lavender': '6,7', 
          'Fern': '7,0', 
          'Ficus': '5,5', 
          'Jade Plant': '6,7', 
          'Tulip': '6,7', 
          'Cactus': '6,5', 
          'Peony': '6,2',
          'Calla Lily': '6,7', 
          'Geranium': '6,7', 
          'Carnation': '6,7', 
          'Lily': '6,7', 
          'Basil': '6,0', 
          'Snake Plant': '6,7', 
          'Anthurium': '6,7',
          'Hydrangea': '6,0', 
          'Aloe Vera': '5,5', 
          'Peperomia': '6,5', 
          'Rosemary': '6,7', 
          'Strawberry': '6,7', 
          'African Violet': '6,0',
          'Begonia': '6,0', 
          'Marigold': '6,2', 
          'Tree Aloe': '6,5', 
          'Dahlia': '6,7', 
          'Gazania': '6,7', 
          'Ivy': '6,7', 
          'Croton': '6,7', 
          'Petunia': '6,7',
          'Climbing Hydrangea': '6,7', 
          'Sea Lavender': '6,5', 
          'Alder': '5,5', 
          'Eucalyptus': '7,0', 
          'Venus Flytrap': '6,5', 
          'Water Lily': '6,5', 
          'Catnip': '4,5', 
          'Pansy': '7,0', 
          'Swedish Ivy': '6,7', 
          'Boston Fern': '6,5'}

# %%
dff['Plant pH'] = dff['Name'].map(dictio3)

# %%
dff.head()
# Out:
#                 Name          Family         Genus         Order  \
# 0            Jasmine        Oleaceae  Jasminum; L.      Lamiales
# 1     Curcuma caesia   Zingiberaceae       Curcuma  Zingiberales
# 2         Curry Tree        Rutaceae       Murraya    Sapindales
# 3  Indian gooseberry  Phyllanthaceae   Phyllanthus  Malpighiales
# 4           Hibiscus       Malvaceae      Hibiscus      Malvales
#
#   Suitable Soil pH        Watering Frequency Placement Plant pH
# 0          4.9-8.3  regularly (2-3 per week)   Outdoor      6,6
# 1          4.5-6.5    regularly (2 per week)   Outdoor      5,5
# 2            5.6-6    regularly (2 per week)   Outdoor      5,8
# 3          6.5-9.5  regularly (2-3 per week)   Outdoor      8,0
# 4          5.5-6.5  regularly (1-2 per week)   Outdoor      6,0

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                79 non-null     object
#  1   Family              79 non-null     object
#  2   Genus               79 non-null     object
#  3   Order               79 non-null     object
#  4   Suitable Soil pH    79 non-null     object
#  5   Watering Frequency  79 non-null     object
#  6   Placement           79 non-null     object
#  7   Plant pH            79 non-null     object
# dtypes: object(8)
# memory usage: 5.1+ KB

# %%
dff['Plant pH'] = dff['Plant pH'].str.replace(',', '.')

# %%
dff['Plant pH'] = dff['Plant pH'].astype(float)

# %%
Acidic_Soil_pH = dff[dff['Plant pH'] <= 6.5]['Plant pH'].tolist()

# %%
Neutral_Soil_pH = dff[dff['Plant pH'].between (6.6, 7.3)]['Plant pH'].tolist()

# %%
Alkaline_Soil_pH = dff[dff['Plant pH'] >= 7.4]['Plant pH'].tolist()

# %%
print(Alkaline_Soil_pH)
# Out:
# [8.0, 9.2]

# %%
print(Neutral_Soil_pH)
# Out:
# [6.6, 6.8, 6.7, 7.0, 7.2, 7.2, 6.9, 7.0, 7.0, 7.2, 6.9, 6.7, 7.0, 6.7, 7.0, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 6.7, 7.0, 7.0, 6.7]

# %%
print(Acidic_Soil_pH)
# Out:
# [5.5, 5.8, 6.0, 6.0, 6.0, 6.0, 6.5, 6.5, 6.5, 6.5, 6.2, 5.4, 6.2, 5.8, 6.2, 5.8, 5.5, 6.5, 6.5, 6.5, 6.0, 4.2, 6.3, 6.0, 6.5, 5.5, 6.5, 6.2, 6.0, 6.0, 5.5, 6.5, 6.0, 6.0, 6.2, 6.5, 6.5, 5.5, 6.5, 6.5, 4.5, 6.5]

# %%
empty_dict = {key: '' for key in dictio}
print(empty_dict)
# Out:
# {'Jasmine': '', 'Curcuma caesia': '', 'Curry Tree': '', 'Indian gooseberry': '', 'Hibiscus': '', 'Rose apple': '', 'Passiflora incarnata (Purple)': '', 'White-fleshed pitahaya': '', 'Chrysanthemums': '', 'Mentha': '', 'Sapodilla': '', 'Snake gourd': '', 'Key lime': '', 'Cucumber': '', 'Trailing arbutus': '', 'Betel': '', 'Rose': '', 'Wild sweetsop': '', 'Jack tree': '', 'Cymbopogon citratus': '', 'Amorphophallus paeoniifol
=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/gettyimages-970984818-2000-4a2ce04f15f24a75bbb70a1d4e65c714.jpg',
 'Catnip': 'https://www.consumer.es/app/uploads/2019/07/img_gatos-catnip-hierbas.jpg',
 'Pansy': 'https://ferrymorse.com/cdn/shop/products/6218_SwissGiantsMixedColorsPansyseeds_FerryMorse.jpg?v=1609782542',
 'Swedish Ivy': 'https://i.etsystatic.com/22817684/r/il/993ebb/3013372531/il_fullxfull.3013372531_5m95.jpg',
 'Boston Fern': 'https://gardenerspath.com/wp-content/uploads/2022/04/Large-Boston-Fern-Growing-in-a-Pot-Outdoors.jpg'}

# %%
dff['Img url'] = dff['Name'].map(dictioimg)

# %%
dictiocont = {
    'Jasmine': 'Asia',
    'Curcuma caesia': 'Asia',
    'Curry Tree': 'Asia',
    'Indian gooseberry': 'Asia',
    'Hibiscus': 'Asia',
    'Rose apple': 'Asia',
    'Passiflora incarnata (Purple)': 'North America',
    'White-fleshed pitahaya': 'South America',
    'Chrysanthemums': 'Asia',
    'Mentha': 'Europe',
    'Sapodilla': 'North America',
    'Snake gourd': 'Asia',
    'Key lime': 'North America',
    'Cucumber': 'Asia',
    'Trailing arbutus': 'North America',
    'Betel': 'Asia',
    'Rose': 'Asia',
    'Wild sweetsop': 'South America',
    'Jack tree': 'Asia',
    'Cymbopogon citratus': 'Asia',
    'Amorphophallus paeoniifolius': 'Asia',
    'Chamaecostus cuspidatus': 'Asia',
    'Nyctanthes arbor-tristis': 'Asia',
    'Amaranthus': 'America',
    'Calabash': 'Africa',
    'Saussurea obvallata': 'Asia',
    'Leonotis nepetifolia': 'Africa',
    'Lawsonia inermis(Henna)': 'Africa',
    'Spine gourd': 'Asia',
    'Clitoria ternatea': 'Asia',
    'Ziziphus mauritiana': 'Africa',
    'Tinospora cordifolia': 'Asia',
    'Moringa oleifera': 'Asia',
    'Mangifera indica': 'Asia',
    'Echinochloa colona': 'Asia',
    'Ocimum tenuiflorum': 'Asia',
    'Ajwain': 'Asia',
    'Camellia sinensis': 'Asia',
    'Aegle marmelos': 'Asia',
    'Epipremnum aureum': 'Asia',
    'Orchid': 'Worldwide',
    'Tomato': 'America',
    'Sunflower': 'Worldwide',
    'Lavender': 'Worldwide',
    'Fern': 'Worldwide',
    'Ficus': 'Worldwide',
    'Jade Plant': 'Africa',
    'Tulip': 'Europe',
    'Cactus': 'America',
    'Peony': 'Worldwide',
    'Calla Lily': 'Africa',
    'Geranium': 'Africa',
    'Carnation': 'Worldwide',
    'Lily': 'Worldwide',
    'Basil': 'Worldwide',
    'Snake Plant': 'Africa',
    'Anthurium': 'America',
    'Hydrangea': 'Worldwide',
    'Aloe Vera': 'Africa',
    'Peperomia': 'South America',
    'Rosemary': 'Worldwide',
    'Strawberry': 'Worldwide',
    'African Violet': 'Africa',
    'Begonia': 'Worldwide',
    'Marigold': 'Worldwide',
    'Tree Aloe': 'Africa',
    'Dahlia': 'America',
    'Gazania': 'Africa',
    'Ivy': 'Worldwide',
    'Croton': 'Worldwide',
    'Petunia': 'America',
    'Climbing Hydrangea': 'Asia',
    'Sea Lavender': 'Europe',
    'Alder': 'Worldwide',
    'Eucalyptus': 'Oceania',
    'Venus Flytrap': 'North America',
    'Water Lily': 'Worldwide',
    'Catnip': 'Europe',
    'Pansy': 'Europe',
    'Swedish Ivy': 'Africa',
    'Boston Fern': 'Worldwide'
}

# %%
dff['Region'] = dff['Name'].map(dictiocont)

# %%
dff['Genus'] = dff['Genus'].str.replace('; L.', '')
# Out:
# C:\Users\FX506\AppData\Local\Temp\ipykernel_33496\2499391466.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dff['Genus'] = dff['Genus'].str.replace('; L.', '')

# %%
# Generar datos aleatorios
x = dff['Plant pH']
y = dff['Region']

# Crear el scatter plot
fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(x, y)

# Configurar el título y las etiquetas de los ejes
ax.set_title('Plant distribution per pH and Region')
ax.set_xlabel('Plant pH')
ax.set_ylabel('Region')
# Out:
# Text(0, 0.5, 'Region')

# %%
dff['Watering Frequency'].isna().value_counts()
# Out:
# False    79
# Name: Watering Frequency, dtype: int64

# %%
regularly = dff[dff['Watering Frequency'].str.contains('regularly', case=False)]['Watering Frequency'].tolist()

# %%
periodically = dff[dff['Watering Frequency'].str.contains('periodically', case=False)]['Watering Frequency'].tolist()

# %%
occasionally = dff[dff['Watering Frequency'].str.contains('occasionally', case=False)]['Watering Frequency'].tolist()

# %%
dff['Watering Frequency'].isna().value_counts()
# Out:
# False    79
# Name: Watering Frequency, dtype: int64

# %%
columns_order = ['Name', 'Family', 'Genus', 'Order', 'Plant pH', 'Suitable Soil pH', 'Placement', 'Watering Frequency', 'Region', 'Img url']

dff = dff.reindex(columns=columns_order)

# %%
dff['Watering Frequency'].isna().value_counts()
# Out:
# False    79
# Name: Watering Frequency, dtype: int64

# %%
dff.head(1)
# Out:
#       Name    Family     Genus     Order  Plant pH Suitable Soil pH Placement  \
# 0  Jasmine  Oleaceae  Jasminum  Lamiales       6.6          4.9-8.3   Outdoor
#
#          Watering Frequency Region  \
# 0  regularly (2-3 per week)   Asia
#
#                                                                                                                                                                             Img url
# 0  https://media.istockphoto.com/id/1134069126/es/foto/rama-de-jazm%C3%ADn-flores-aisladas-sobre-fondo-blanco.jpg?s=612x612&w=0&k=20&c=kaMKhijyq8SMB6qksaZJAX8IzzsTtLs86a49tZfvv7g=

# %%
dff.to_csv('Plants_To_Plant_2.csv')

# %%
df2 = dff.drop('Img url', axis=1)

# %%
df2.head(1)
# Out:
#       Name    Family     Genus     Order  Plant pH Suitable Soil pH Placement  \
# 0  Jasmine  Oleaceae  Jasminum  Lamiales       6.6          4.9-8.3   Outdoor
#
#          Watering Frequency Region
# 0  regularly (2-3 per week)   Asia

# %%
df2.to_csv('Plants_no_img.csv')

# %%
dff
# Out:
#                              Name           Family              Genus  \
# 0                         Jasmine         Oleaceae           Jasminum
# 1                  Curcuma caesia    Zingiberaceae            Curcuma
# 2                      Curry Tree         Rutaceae            Murraya
# 3               Indian gooseberry   Phyllanthaceae        Phyllanthus
# 4                        Hibiscus        Malvaceae           Hibiscus
# 5                      Rose apple        Myrtaceae           Syzygium
# 6   Passiflora incarnata (Purple)   Passifloraceae         Passiflora
# 7          White-fleshed pitahaya        Cactaceae       Selenicereus
# 8                  Chrysanthemums       Asteraceae      Chrysanthemum
# 9                          Mentha            Mints             Mentha
# 10                      Sapodilla       Sapotaceae          Manilkara
# 11                    Snake gourd    Cucurbitaceae      Trichosanthes
# ...
